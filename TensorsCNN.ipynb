# %% [markdown]
# <a href="https://colab.research.google.com/github/ReallyABot/Codemy-Pytorch-Youtube/blob/main/TensorsCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2+5
# Out:
# 7

# %%
78+95
# Out:
# 173
